# %% [markdown]
# # string

# %% [markdown]
# e usado principalmente para armazenar informaçoes de texto. Nelas temos uma sequencia de caracteres que formam um texto. O Python permite formar strings com aspas simples e duplas

# %%
"joao"=="JOAO" # o python diferencia as letras maiuscula de minusculas
# Out:
# False

# %%
nome = "beato"
sobrenome = "Ushiromiya"
nome_completo = nome + " " + sobrenome
print(nome_completo)
# Out:
# beato Ushiromiya

# %% [markdown]
# # f-string

# %% [markdown]
# string literais formatadas

# %%
idade =  20

# %%
print(nome, sobrenome, idade) # as virgulas sao maneiras de chamar variaveis diferentes
# Out:
# beato Ushiromiya 20

# %%
print(f"{nome} {sobrenome} tem {idade} anos") # f na frente do print informa que estamos formatando o print
# Out:
# beato Ushiromiya tem 20 anos

# %%
linguagem = "python"
print(f"adoro programar em {linguagem}")
# Out:
# adoro programar em python

# %% [markdown]
# # strings sao objetos  iteraveis

# %%
nome = "violet" # o python entende uma palavra como uma lista de letras, entao podemos percorrer essa lista e capturar os elementos que desejamos uma lista sempre inicia pelo indice ZERO

# %%
print(nome)
# Out:
# violet

# %%
nome [0]
# Out:
# 'v'

# %%
nome[-1]
# Out:
# 't'

# %%
nome[-1] # podemos acessar o ultimo elemento de uma lista atraves do indice -1
# Out:
# 't'

# %% [markdown]
# # entrada de dados com a funçao input()

# %% [markdown]
# e muito comum em programaçao que  o usuario passe algum tipo de dado

# %%
input("digite seu nome: ")

# %%
nome = input("digite seu nome: ")
# Out:
# digite seu nome: beato

# %%
print(nome)
# Out:
# beato

# %%
# para fazer uma operaçao matematica precisamos informar qual tipo e o dado
num1 = input("digite um numero: ")
num2 = input("digite outro numero: ")
print(num1 + num2)
# Out:
# digite um numero: 6
# digite outro numero: 7
# 67

# %%
# para fazer uma operaçao matematica precisamos informar qual tipo e o dado
num1 =int (input("digite um numero: "))
num2 =int(input("digite outro numero: "))
print(num1 + num2)
# Out:
# digite um numero: 60
# digite outro numero: 7
# 67

# %%
soma = num1 + num2
print(soma)
# Out:
# 67

# %%
nota1 = float(input("digite a primeira nota: "))
nota2 = float(input("digite a segunda nota: "))
media = (nota1 + nota2)/2
print(f"o aluno(a) teve notas {nota1}, {nota2} e sua media foi {media}")
# Out:
# digite a primeira nota: 5.7
# digite a segunda nota: 3.9
# o aluno(a) teve notas 5.7, 3.9 e sua media foi 4.8

# %% [markdown]
# # operadores aritmeticos

# %% [markdown]
# adiçao (+)

# %%
print(10 + 20)
print(10 + 20.5)
print(10 + 20 + 40)
# Out:
# 30
# 30.5
# 70

# %%
print(-89 + 63) # print() e uma funçao de saida de python
print(23 - 17) # 23 + (-17)
print(24 + -67) # 24 + (-67)
print(34 - 67) # 34 + (-67)
# Out:
# -26
# 6
# -43
# -33

# %% [markdown]
# # subtraçao

# %%
print(123-87)
# Out:
# 36

# %% [markdown]
# ## multiplicaçao(*)

# %%
print(10*2)
# Out:
# 20

# %%
print(2.4*2.5)
# Out:
# 6.0

# %% [markdown]
# ## divisao(/)

# %%
print(1000/10)
print(129/23)
# Out:
# 100.0
# 5.608695652173913

# %% [markdown]
# divisao com resultado inteiro(//)

# %%
print(129//23)
# Out:
# 5

# %% [markdown]
# ## exponenciaçao

# %%
print(2**5)
# Out:
# 32

# %%
print(2**-1)
# Out:
# 0.5

# %%
print(2**-1.5)
# Out:
# 0.3535533905932738

# %% [markdown]
# # precedencia

# %% [markdown]
# 1. pareneteses
# 2. expoentes
# 3. multiplicaçao  e divisao ( da esquerda pra direita)
# 4. somas e subtraçao

# %%
5 + 25 * 2
# Out:
# 55

# %%
(5 + 25) * 2
# Out:
# 60

# %%
(12 + 3 - 1 * 50/3)
# Out:
# -1.6666666666666679

# %% [markdown]
# radiciaçao

# %%
4 ** 0.5
# Out:
# 2.0

# %% [markdown]
# # hora da pratica

# %% [markdown]
# 1. crie um codigo que receba o nome do aluno e informe a media do aluno obs:no seu print voce deve apresentar o nome do aluno, as dua notas e a media
#
# 2. crie um codigo que receba as medidas de um retangulo e informe o perimetro do mesmo
#
# 3. crie um codigo que calcule a raiz quadrada de um numero
#
# 4. crie uma calculadora simples (adicao,subtraçao, multiplicaçao, divisao) seu codigo deve receber 2 numeros e apresentar o resultado das 4 operaçoes
# 5. calcule a diferença
# 6. calcule o produto entre dois numeros
# 7. crie um codigo que receba uma base e depois o expoente e calcule a potencia
# 8. crie um programa que solicite ao usuario a quantidade de horas trabalhadas por semana e o valor da hora de trabalho e calcule o salario

# %%
input("digite seu nome: ")
nota1 = float(input("digite sua nota: "))
nota2 = float(input("digite sua nota: "))
media = (nota1 +nota2)/2
print(f"o aluno(a) teve notas{nota1},{nota2} e sua media foi{media}")
# Out:
# digite seu nome: Rize
# digite sua nota: 3.5
# digite sua nota: 2.5
# o aluno(a) teve notas3.5,2.5 e sua media foi3.0

# %%
largura = float(input("digite sua largura: "))
altura  = float(input("digite sua altura:  "))
perimetro = 2* (largura + altura)
print(f"o perimetro do retangulo é {perimetro}")
# Out:
# digite sua largura: 20
# digite sua altura:  50
# o perimetro do retangulo é 140.0

# %%
num1 = float(input("digite um numero: "))
raiz = num1 ** 0.5
print(f"a raiz quadrada de {num1} é {raiz}")
# Out:
# digite um numero: 8
# a raiz quadrada de 8.0 é 2.8284271247461903

# %%
num1 = float(input("digite seu numero: "))
num2 = float(input("digite um novo numero: "))
soma = num1 + num2
subtracao = num1 - num2
multiplicacao = num1 * num2
divisao = num1 / num2
print(f"o resultado da soma,multiplicaçao,divisao,subtraçao,{num1},{num2} e {soma},{subtracao},{multiplicacao},{divisao:.2f}")
# Out:
# digite seu numero: 5
# digite um novo numero: 10
# o resultado da soma,multiplicaçao,divisao,subtraçao,5.0,10.0 e 15.0,-5.0,50.0,0.50

# %%
num1=float(input("digite um numero: "))
num2=float(input("digite outro numero: "))
subtraçao=num1-num2
print(f"a diferenca entre {num1} e {num2} e {subtraçao}"),
# Out:
# digite um numero: 30
# digite outro numero: 12
# a diferenca entre 30.0 e 12.0 e 18.0

# %%
num1=float(input("digite um numero: "))
num2=float(input("digite outro numero: "))
produto=num1*num2
print(f"a diferenca entre {num1} e {num2} e {produto}"),
# Out:
# digite um numero: 8
# digite outro numero: 4
# a diferenca entre 8.0 e 4.0 e 32.0
# (None,)

# %%
num1=float(input("digite um numero (base): "))
num2=float(input("digite outro numero (expoente): "))
potenciacao=num1**num2
print(f"{num1} elevado ao expoente {num2} vale {potenciacao}"),
# Out:
# digite um numero (base): 2
# digite outro numero (expoente): 10
# 2.0 elevado ao expoente 10.0 vale 1024.0
# (None,)

# %%
horas=float(input("digite o numero de horas trabalhadas: "))
valor=float(input("digite o valor da hora trabalhada R$ "))
calculo=horas * valor
print(f"trabalhando {horas} voce recebera {calculo}")
# Out:
# digite o numero de horas trabalhadas: 24
# digite o valor da hora trabalhada R$ 500
# trabalhando 24.0 voce recebera 12000.0
