# %% [markdown]
# #tutorial variaveis

# %% [markdown]
# ##oque e variaveis

# %% [markdown]
# variaveis sao memorias do computador onde podemos guardar informaçoes(como texto, numeros, resultados de calculos e etc) para usar depois

# %% [markdown]
# variavel com texto (string)

# %%
nome = "michele"
print (nome)
# Out:
# michele

# %%
nome = "kaori"

# %%
print (nome)
# Out:
# michele

# %% [markdown]
# variavel com numero inteiro (int)

# %%
idade = 18
print (idade)
# Out:
# 18

# %%
# esse e um exemplo de numero inteiro negativo
temperatura = -36.5 # esta varialvel esta armazenando um numero negativo
print (temperatura)# print () e uma funçao de saida
# Out:
# 36.5

# %% [markdown]
# variavel com numero decimal (float)

# %%
altura = 1.70 # em python os numemros decimais sao escritos com "." exemplo: "5.2"
print (altura)
# Out:
# 1.7

# %%
pi = 3,14
print (pi)
# Out:
# (3, 14)

# %% [markdown]
# variavel com valor booleano (bool)

# %%
estudante = True
print (estudante)

# %% [markdown]
# ## nomes de variaveis

# %% [markdown]
# pode:
#
# *   comecar com letra exemplos (n, numero, altura)
# *   conter numero, mas nao pode comecar com numeros exemplos (n1, numero1, etc)
#
# nao pode:
#
# *   comecar com numero
# *   usar espaço (nome_completa, nome-completo, nomecompleto)
# *   usar acentuaçao ou caracteres especiais (%, &, #, @)
# *   usar palavras reservadas

# %%
# ERRADO
1idade = 16 # comecar com numero
meu nome = "michele" # espaço nao e permitido

# %% [markdown]
# snake_case e um estilo de escrita usada pra nome de variaveis, funçoes, e nomes em geral no codigo. Neste estilo, as palavras sao todos em minusculas e separada por um underline(_)

# %% [markdown]
# ## por que usar snake_case
#
# *   deixa o codigo mais facil de ler
# *   e o padrao recomendado pela comunidade python
# *   segue a  PEF8,que e o guia de estilo oficial do Python
# OBS:PEF8 e um documento que recomenda boas praticas pra escrever para escrever codigo python limpo e legivel

# %% [markdown]
# ## exemplos que nao usam snake_case

# %%
nomecompleto = "michele" #estilo camelcase (mais comum em javascripit)
nomecompleto = "michele" #estilo pascalcase (usado para classes em Python)
nomecompleto = "michele" #estilo dificil de ler
